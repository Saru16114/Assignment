# %% [markdown]
# # Electrostatic force between the charges

# %% [markdown]
# ## The coulomb's force between two charges $q_1 $and $q_2$ separated at distance $r$ is given as

# %% [markdown]
# ## F=kq1q2/r^2

# %% [markdown]
# ### where k=9*10^9 Nm^2C^-2

# %% [markdown]
# #### Write a code for function to calculate the Coulomb's force between two given charge at given distance.Use list to calculate the variation of Coloumb's force between two charges(as you like)placed at a range of distance (choose range in your favour). Make a plot that shows the variation of Coulomb's force with distance using list.
# #### Let two charges be $q_1$=2C and $q_2$=8C

# %%
k=9*10**9
def force (r,q1,q2): #function to calculate coloumb's force betweem two charges
    return k*q_1*q_2/(r**2)

# %%
#Range of distances
F=[]
R=[]
q_1=2
q_2=8
for r in range(1,100):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
#plot between range of distance vs corresponding Coloumbs Force
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.plot(F,R)

# %%
plt.plot(R,F)

# %%
#Range of distances
F=[]
R=[]
q_1=1
q_2=1.1
for r in range(1,10):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
plt.plot(R,F)

# %%
plt.plot(F,R)

# %%
#Range of distances
F=[]
R=[]
q_1=2
q_2=100
for r in range(1,10):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
plt.plot(F,R)

# %%
#Range of distances
F=[]
R=[]
q_1=100
q_2=1000
for r in range(1,2):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
plt.plot(F,R)

# %%
#Range of distances
F=[]
R=[]
q_1=100
q_2=1000
for r in range(1,100000):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
plt.plot(F,R)

# %%
#Range of distances
F=[]
R=[]
q_1=2
q_2=8
for r in range(1,1000):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
plt.plot(F,R)

# %%
#Range of distances
F=[]
R=[]
q_1=200
q_2=800
for r in range(1,100):
    F.append(force(r,q_1,q_2))
    R.append(r)

# %%
plt.plot(F,R)
